# %% [markdown]
# ## Mitsuba Disk Experiment 1

# %%
import mitsuba              as mi
import matplotlib.pyplot    as plt
mi.variants() # mi.set_variant("llvm_ad_rgb") # mi.set_variant("scalar_rgb") # mi.set_variant("cuda_ad_rgb")
# mi.set_variant("scalar_rgb")
mi.set_variant("llvm_ad_rgb")

# %%
scene   = mi.load_file("../scenes/diskbox.xml")
img1    = mi.render(scene, spp=256)


# plt.figure(figsize=(10,10))
plt.imshow(img1 ** (1.0 / 1.7))
plt.axis("off")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..2.873602].
# (np.float64(-0.5), np.float64(511.5), np.float64(511.5), np.float64(-0.5))

# %% [markdown]
# ## Updating the scene
#
# In this example, the color of the emitter is updated.

# %%
scene  = mi.load_file("../scenes/diskbox.xml")
params = mi.traverse(scene)
print(params)
print(params["spot.intensity.value"])

params["spot.intensity.value"] = [5.0 ,5.0 , 15.0]

params.update()
img1    = mi.render(scene, spp=128)
plt.axis("off")
plt.imshow(img1 ** (1.0 / 1.7))

#print(scene.emitters())



# print(em.intensity)
# print(em.to_world)
def dump(obj):
  for attr in dir(obj):
    print("obj.%s = %r" % (attr, getattr(obj, attr)))
# Out:
# SceneParameters[
#   -------------------------------------------------------------------------------------------
#   Name                                    Flags    Type        Parent
#   -------------------------------------------------------------------------------------------
#   sensor.near_clip                                 float       PerspectiveCamera
#   sensor.far_clip                                  float       PerspectiveCamera
#   sensor.shutter_open                              float       PerspectiveCamera
#   sensor.shutter_open_time                         float       PerspectiveCamera
#   sensor.film.size                                 Vector2u    HDRFilm
#   sensor.film.crop_size                            Vector2u    HDRFilm
#   sensor.film.crop_offset                          Point2u     HDRFilm
#   sensor.x_fov                            ∂, D     float       PerspectiveCamera
#   sensor.principal_point_offset_x         ∂, D     float       PerspectiveCamera
#   sensor.principal_point_offset_y         ∂, D     float       PerspectiveCamera
#   sensor.to_world                         ∂, D     Transform4f PerspectiveCamera
#   gray.reflectance.value                  ∂        Color3f     SRGBReflectanceSpectrum
#   white.reflectance.value                 ∂        Color3f     SRGBReflectanceSpectrum
#   bright.reflectance.value                ∂        Color3f     SRGBReflectanceSpectrum
#   green.reflectance.value                 ∂        Color3f     SRGBReflectanceSpectrum
#   red.reflectance.value                   ∂        Color3f     SRGBReflectanceSpectrum
#   mirror.eta.value                        ∂, D     Color3f     SRGBReflectanceSpectrum
#   mirror.k.value                          ∂, D     Color3f     SRGBReflectanceSpectrum
#   mirror.specular_reflectance.value       ∂        float       UniformSpectrum
#   glass.eta                                        float       SmoothDielectric
#   spot.sampling_weight                             float       SpotLight
#   spot.intensity.value                    ∂        Color3f     SRGBReflectanceSpectrum
#   spot.texture.value                      ∂        float       UniformSpectrum
#   spot.to_world                                    Transform4f SpotLight
#   light.emitter.sampling_weight                    float       AreaLight
#   light.emitter.radiance.value            ∂        Color3f     SRGBReflectanceSpectrum
#   light.silhouette_sampling_weight                 float       OBJMesh
#   light.faces                                      ArrayXu     OBJMesh
#   light.vertex_positions                  ∂, D     ArrayXf     OBJMesh
#   light.vertex_normals                    ∂, D     ArrayXf     OBJMesh
#   light.vertex_texcoords                  ∂        ArrayXf     OBJMesh
#   disk.silhouette_sampling_weight                  float       Disk
#   disk.to_world                           ∂, D     Transform4f Disk
#   floor.silhouette_sampling_weight                 float       OBJMesh
#   floor.faces                                      ArrayXu     OBJMesh
#   floor.vertex_positions                  ∂, D     ArrayXf     OBJMesh
#   floor.vertex_normals                    ∂, D     ArrayXf     OBJMesh
#   floor.vertex_texcoords                  ∂        ArrayXf     OBJMesh
#   ceiling.silhouette_sampling_weight               float       OBJMesh
#   ceiling.faces                                    ArrayXu     OBJMesh
#   ceiling.vertex_positions                ∂, D     ArrayXf     OBJMesh
#   ceiling.vertex_normals                  ∂, D     ArrayXf     OBJMesh
#   ceiling.vertex_texcoords                ∂        ArrayXf     OBJMesh
#   back.silhouette_sampling_weight                  float       OBJMesh
#   back.faces                                       ArrayXu     OBJMesh
#   back.vertex_positions                   ∂, D     ArrayXf     OBJMesh
#   back.vertex_normals                     ∂, D     ArrayXf     OBJMesh
#   back.vertex_texcoords                   ∂        ArrayXf     OBJMesh
#   greenwall.silhouette_sampling_weight             float       OBJMesh
#   greenwall.faces                                  ArrayXu     OBJMesh
#   greenwall.vertex_positions              ∂, D     ArrayXf     OBJMesh
#   greenwall.vertex_normals                ∂, D     ArrayXf     OBJMesh
#   greenwall.vertex_texcoords              ∂        ArrayXf     OBJMesh
#   redwall.silhouette_sampling_weight               float       OBJMesh
#   redwall.faces                                    ArrayXu     OBJMesh
#   redwall.vertex_positions                ∂, D     ArrayXf     OBJMesh
#   redwall.vertex_normals                  ∂, D     ArrayXf     OBJMesh
#   redwall.vertex_texcoords                ∂        ArrayXf     OBJMesh
# ]
# [9.0, 10.0, 11.0]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.6950285].
