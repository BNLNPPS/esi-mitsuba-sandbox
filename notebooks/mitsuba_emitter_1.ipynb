# %% [markdown]
# ## Mitsuba Emitter Experiment 1

# %%
import mitsuba              as mi
import matplotlib.pyplot    as plt
mi.variants()
# Out:
# ['scalar_rgb', 'scalar_spectral', 'cuda_ad_rgb', 'llvm_ad_rgb']

# %%
# mi.set_variant("llvm_ad_rgb") # mi.set_variant("scalar_rgb") # mi.set_variant("cuda_ad_rgb")

mi.set_variant("scalar_rgb")

# %% [markdown]
# ## Scenes
#
# We are using two scenes, the _spotbox_ and the _emitbox_ to study different aspects of raytracing.

# %%
scene   = mi.load_file("../scenes/emitbox.xml")
img1    = mi.render(scene, spp=128)

plt.axis("off") # plt.figure(figsize = (10,10)) # plt.rcParams["figure.figsize"] = (20,10)
plt.imshow(img1); # approximate sRGB tonemapping  ** (1.0 / 1.7
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.077133].

# %%
scene   = mi.load_file("../scenes/spotbox.xml")
img1    = mi.render(scene, spp=1024)
plt.axis("off")
plt.imshow(img1 ** (1.0 / 1.7))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..2.234651].

# %%
scene   = mi.load_file("../scenes/diskbox.xml")
img1    = mi.render(scene, spp=128)
plt.axis("off")
plt.imshow(img1 ** (1.0 / 1.7))

# %% [markdown]
# ## Updating the scene
#
# In this example, the color of the emitter is updated.

# %%
scene   = mi.load_file("../scenes/diskbox.xml")
params  = mi.traverse(scene)
# print(params)
#print(params["SpotLight.intensity.value"])

params['SpotLight.intensity.value'] = [1., 10., 10.]
params.update();
img1    = mi.render(scene, spp=128)
plt.axis("off")
plt.imshow(img1 ** (1.0 / 1.7))

# %%
scene  = mi.load_file("../scenes/diskbox.xml")
params = mi.traverse(scene)
# print(params)





#print(scene.emitters())

#print(params["SpotLight.intensity.value"])
#print(params["SpotLight.to_world"])

# params["xxx.cutoff_angle.value"]
# print(params["SpotLight.cutoff_angle.value"])
# ems = scene.emitters()
em = ems[0]
# dir(PyCapsule)

# print(em.intensity)
# print(em.to_world)
def dump(obj):
  for attr in dir(obj):
    print("obj.%s = %r" % (attr, getattr(obj, attr)))

# print(em.m_cutoff_angle)
# dump(em)
# params['SpotLight.cutoff_angle.value'] = 5.0
#params.update();
#print(params)
