# %% [markdown]
# ## Mitsuba Emitter Experiment 1

# %%
import mitsuba as mi
import matplotlib.pyplot as plt

# %%
mi.variants()
# Out:
# ['scalar_rgb', 'scalar_spectral', 'cuda_ad_rgb', 'llvm_ad_rgb']

# %%
mi.set_variant("llvm_ad_rgb")
# mi.set_variant("scalar_rgb")
# mi.set_variant("cuda_ad_rgb")

# %%
scene = mi.load_file("../scenes/emitbox.xml")
img1 = mi.render(scene, spp=256)
plt.axis("off")
# plt.figure(figsize = (10,10))
# plt.rcParams["figure.figsize"] = (20,10)
plt.imshow(img1 ** (1.0 / 1.7)); # approximate sRGB tonemapping
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0434804].

# %%
scene = mi.load_file("../scenes/spotbox.xml")
img1 = mi.render(scene, spp=256)
plt.imshow(img1 ** (1.0 / 1.7))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.3414956].
